# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Landscape.gene.expr_v2.csv")
df = df.iloc[:, :-2]

df
# Out:
#                     gene  Cardiomyocyte  Endothelial cell  Enterocyte  \
# 0                  ABCF3       0.026038          0.004543    0.006924
# 1                  ACSF3       0.007610          0.002715    0.014500
# 2                  ACTC1       0.134776          0.000388    0.000131
# 3                 ADAM12       0.001559          0.000111    0.000392
# 4               ADAMTSL4       0.000550          0.002881    0.000392
# ...                  ...            ...               ...         ...
# 27533         CR478208.1       0.000000          0.000000    0.000000
# 27534         CU469530.2       0.000000          0.000000    0.000000
# 27535         BX119915.3       0.000000          0.000000    0.000000
# 27536            pimr161       0.000000          0.000000    0.000000
# 27537  si:ch211-226o13.3       0.000000          0.000000    0.000000
#
#        Epithelial cell  Epithelial cell (Brain)  Erythrocyte  \
# 0             0.011201                 0.014049     0.008117
# 1             0.005950                 0.005534     0.002156
# 2             0.000593                 0.001277     0.001205
# 3             0.000153                 0.001703     0.000127
# 4             0.000794                 0.001277     0.000254
# ...                ...                      ...          ...
# 27533         0.000000                 0.000000     0.000000
# 27534         0.000000                 0.000000     0.000000
# 27535         0.000000                 0.000000     0.000000
# 27536         0.000000                 0.000000     0.000000
# 27537         0.000000                 0.000000     0.000000
#
#        Erythrocyte (Liver)  Erythroid Progenitor cell  Fibroblast  ...  \
# 0                 0.005185                   0.042570    0.012821  ...
# 1                 0.004148                   0.014190    0.000000  ...
# 2                 0.000519                   0.000535    0.000000  ...
# 3                 0.000000                   0.000000    0.000000  ...
# 4                 0.000000                   0.000000    0.006410  ...
# ...                    ...                        ...         ...  ...
# 27533             0.000000                   0.000000    0.000000  ...
# 27534             0.000000                   0.000000    0.000000  ...
# 27535             0.000000                   0.000000    0.000000  ...
# 27536             0.000000                   0.000000    0.000000  ...
# 27537             0.000000                   0.000000    0.000000  ...
#
#        Pancreatic cell  Pancreatic Macrophage  Primordial Germ cell  \
# 0             0.006537               0.000000              0.049889
# 1             0.003230               0.007812              0.026436
# 2             0.000769               0.007812              0.001080
# 3             0.000385               0.000000              0.000103
# 4             0.000615               0.000000              0.000566
# ...                ...                    ...                   ...
# 27533         0.000000               0.000000              0.000000
# 27534         0.000000               0.000000              0.000000
# 27535         0.000000               0.000000              0.000000
# 27536         0.000000               0.000000              0.000000
# 27537         0.000000               0.000000              0.000000
#
#        Radial Glia  Retinal cell  Retinal Cone cell  \
# 0         0.011990      0.012217           0.011561
# 1         0.005185      0.003620           0.002668
# 2         0.001080      0.000905           0.002668
# 3         0.000432      0.000000           0.000889
# 4         0.001728      0.000452           0.000000
# ...            ...           ...                ...
# 27533     0.000000      0.000000           0.000000
# 27534     0.000000      0.000000           0.000000
# 27535     0.000000      0.000000           0.000000
# 27536     0.000000      0.000000           0.000000
# 27537     0.000000      0.000000           0.000000
#
#        Retinal Pigment Epithelial cell  Smooth Muscle cell  Spermatocyte  \
# 0                             0.020756            0.009735      0.011445
# 1                             0.005535            0.005361      0.018810
# 2                             0.001384            0.000988      0.000680
# 3                             0.001845            0.000282      0.000113
# 4                             0.002306            0.003527      0.000453
# ...                                ...                 ...           ...
# 27533                         0.000000            0.000000      0.000000
# 27534                         0.000000            0.000000      0.000000
# 27535                         0.000000            0.000000      0.000000
# 27536                         0.000000            0.000000      0.000000
# 27537                         0.000000            0.000000      0.000000
#
#          T cell
# 0      0.007342
# 1      0.004339
# 2      0.000273
# 3      0.000091
# 4      0.000455
# ...         ...
# 27533  0.000000
# 27534  0.000000
# 27535  0.000000
# 27536  0.000000
# 27537  0.000000
#
# [27538 rows x 42 columns]

# %%
df = df.rename(columns={s:s.replace("pct.", "") for s in df.columns})
df
# Out:
#                     gene  Cardiomyocyte  Endothelial cell  Enterocyte  \
# 0                  ABCF3       0.026038          0.004543    0.006924
# 1                  ACSF3       0.007610          0.002715    0.014500
# 2                  ACTC1       0.134776          0.000388    0.000131
# 3                 ADAM12       0.001559          0.000111    0.000392
# 4               ADAMTSL4       0.000550          0.002881    0.000392
# ...                  ...            ...               ...         ...
# 27533         CR478208.1       0.000000          0.000000    0.000000
# 27534         CU469530.2       0.000000          0.000000    0.000000
# 27535         BX119915.3       0.000000          0.000000    0.000000
# 27536            pimr161       0.000000          0.000000    0.000000
# 27537  si:ch211-226o13.3       0.000000          0.000000    0.000000
#
#        Epithelial cell  Epithelial cell (Brain)  Erythrocyte  \
# 0             0.011201                 0.014049     0.008117
# 1             0.005950                 0.005534     0.002156
# 2             0.000593                 0.001277     0.001205
# 3             0.000153                 0.001703     0.000127
# 4             0.000794                 0.001277     0.000254
# ...                ...                      ...          ...
# 27533         0.000000                 0.000000     0.000000
# 27534         0.000000                 0.000000     0.000000
# 27535         0.000000                 0.000000     0.000000
# 27536         0.000000                 0.000000     0.000000
# 27537         0.000000                 0.000000     0.000000
#
#        Erythrocyte (Liver)  Erythroid Progenitor cell  Fibroblast  ...  \
# 0                 0.005185                   0.042570    0.012821  ...
# 1                 0.004148                   0.014190    0.000000  ...
# 2                 0.000519                   0.000535    0.000000  ...
# 3                 0.000000                   0.000000    0.000000  ...
# 4                 0.000000                   0.000000    0.006410  ...
# ...                    ...                        ...         ...  ...
# 27533             0.000000                   0.000000    0.000000  ...
# 27534             0.000000                   0.000000    0.000000  ...
# 27535             0.000000                   0.000000    0.000000  ...
# 27536             0.000000                   0.000000    0.000000  ...
# 27537             0.000000                   0.000000    0.000000  ...
#
#        Pancreatic cell  Pancreatic Macrophage  Primordial Germ cell  \
# 0             0.006537               0.000000              0.049889
# 1             0.003230               0.007812              0.026436
# 2             0.000769               0.007812              0.001080
# 3             0.000385               0.000000              0.000103
# 4             0.000615               0.000000              0.000566
# ...                ...                    ...                   ...
# 27533         0.000000               0.000000              0.000000
# 27534         0.000000               0.000000              0.000000
# 27535         0.000000               0.000000              0.000000
# 27536         0.000000               0.000000              0.000000
# 27537         0.000000               0.000000              0.000000
#
#        Radial Glia  Retinal cell  Retinal Cone cell  \
# 0         0.011990      0.012217           0.011561
# 1         0.005185      0.003620           0.002668
# 2         0.001080      0.000905           0.002668
# 3         0.000432      0.000000           0.000889
# 4         0.001728      0.000452           0.000000
# ...            ...           ...                ...
# 27533     0.000000      0.000000           0.000000
# 27534     0.000000      0.000000           0.000000
# 27535     0.000000      0.000000           0.000000
# 27536     0.000000      0.000000           0.000000
# 27537     0.000000      0.000000           0.000000
#
#        Retinal Pigment Epithelial cell  Smooth Muscle cell  Spermatocyte  \
# 0                             0.020756            0.009735      0.011445
# 1                             0.005535            0.005361      0.018810
# 2                             0.001384            0.000988      0.000680
# 3                             0.001845            0.000282      0.000113
# 4                             0.002306            0.003527      0.000453
# ...                                ...                 ...           ...
# 27533                         0.000000            0.000000      0.000000
# 27534                         0.000000            0.000000      0.000000
# 27535                         0.000000            0.000000      0.000000
# 27536                         0.000000            0.000000      0.000000
# 27537                         0.000000            0.000000      0.000000
#
#          T cell
# 0      0.007342
# 1      0.004339
# 2      0.000273
# 3      0.000091
# 4      0.000455
# ...         ...
# 27533  0.000000
# 27534  0.000000
# 27535  0.000000
# 27536  0.000000
# 27537  0.000000
#
# [27538 rows x 42 columns]

# %%
df = df.set_index("gene")
df.to_csv("Landscape.gene.expr.truncated.csv")
df
# Out:
#                    Cardiomyocyte  Endothelial cell  Enterocyte  \
# gene
# ABCF3                   0.026038          0.004543    0.006924
# ACSF3                   0.007610          0.002715    0.014500
# ACTC1                   0.134776          0.000388    0.000131
# ADAM12                  0.001559          0.000111    0.000392
# ADAMTSL4                0.000550          0.002881    0.000392
# ...                          ...               ...         ...
# CR478208.1              0.000000          0.000000    0.000000
# CU469530.2              0.000000          0.000000    0.000000
# BX119915.3              0.000000          0.000000    0.000000
# pimr161                 0.000000          0.000000    0.000000
# si:ch211-226o13.3       0.000000          0.000000    0.000000
#
#                    Epithelial cell  Epithelial cell (Brain)  Erythrocyte  \
# gene
# ABCF3                     0.011201                 0.014049     0.008117
# ACSF3                     0.005950                 0.005534     0.002156
# ACTC1                     0.000593                 0.001277     0.001205
# ADAM12                    0.000153                 0.001703     0.000127
# ADAMTSL4                  0.000794                 0.001277     0.000254
# ...                            ...                      ...          ...
# CR478208.1                0.000000                 0.000000     0.000000
# CU469530.2                0.000000                 0.000000     0.000000
# BX119915.3                0.000000                 0.000000     0.000000
# pimr161                   0.000000                 0.000000     0.000000
# si:ch211-226o13.3         0.000000                 0.000000     0.000000
#
#                    Erythrocyte (Liver)  Erythroid Progenitor cell  Fibroblast  \
# gene
# ABCF3                         0.005185                   0.042570    0.012821
# ACSF3                         0.004148                   0.014190    0.000000
# ACTC1                         0.000519                   0.000535    0.000000
# ADAM12                        0.000000                   0.000000    0.000000
# ADAMTSL4                      0.000000                   0.000000    0.006410
# ...                                ...                        ...         ...
# CR478208.1                    0.000000                   0.000000    0.000000
# CU469530.2                    0.000000                   0.000000    0.000000
# BX119915.3                    0.000000                   0.000000    0.000000
# pimr161                       0.000000                   0.000000    0.000000
# si:ch211-226o13.3             0.000000                   0.000000    0.000000
#
#                    Goblet cell  ...  Pancreatic cell  Pancreatic Macrophage  \
# gene                            ...
# ABCF3                 0.008792  ...         0.006537               0.000000
# ACSF3                 0.010600  ...         0.003230               0.007812
# ACTC1                 0.000657  ...         0.000769               0.007812
# ADAM12                0.000082  ...         0.000385               0.000000
# ADAMTSL4              0.000493  ...         0.000615               0.000000
# ...                        ...  ...              ...                    ...
# CR478208.1            0.000000  ...         0.000000               0.000000
# CU469530.2            0.000000  ...         0.000000               0.000000
# BX119915.3            0.000000  ...         0.000000               0.000000
# pimr161               0.000000  ...         0.000000               0.000000
# si:ch211-226o13.3     0.000000  ...         0.000000               0.000000
#
#                    Primordial Germ cell  Radial Glia  Retinal cell  \
# gene
# ABCF3                          0.049889     0.011990      0.012217
# ACSF3                          0.026436     0.005185      0.003620
# ACTC1                          0.001080     0.001080      0.000905
# ADAM12                         0.000103     0.000432      0.000000
# ADAMTSL4                       0.000566     0.001728      0.000452
# ...                                 ...          ...           ...
# CR478208.1                     0.000000     0.000000      0.000000
# CU469530.2                     0.000000     0.000000      0.000000
# BX119915.3                     0.000000     0.000000      0.000000
# pimr161                        0.000000     0.000000      0.000000
# si:ch211-226o13.3              0.000000     0.000000      0.000000
#
#                    Retinal Cone cell  Retinal Pigment Epithelial cell  \
# gene
# ABCF3                       0.011561                         0.020756
# ACSF3                       0.002668                         0.005535
# ACTC1                       0.002668                         0.001384
# ADAM12                      0.000889                         0.001845
# ADAMTSL4                    0.000000                         0.002306
# ...                              ...                              ...
# CR478208.1                  0.000000                         0.000000
# CU469530.2                  0.000000                         0.000000
# BX119915.3                  0.000000                         0.000000
# pimr161                     0.000000                         0.000000
# si:ch211-226o13.3           0.000000                         0.000000
#
#                    Smooth Muscle cell  Spermatocyte    T cell
# gene
# ABCF3                        0.009735      0.011445  0.007342
# ACSF3                        0.005361      0.018810  0.004339
# ACTC1                        0.000988      0.000680  0.000273
# ADAM12                       0.000282      0.000113  0.000091
# ADAMTSL4                     0.003527      0.000453  0.000455
# ...                               ...           ...       ...
# CR478208.1                   0.000000      0.000000  0.000000
# CU469530.2                   0.000000      0.000000  0.000000
# BX119915.3                   0.000000      0.000000  0.000000
# pimr161                      0.000000      0.000000  0.000000
# si:ch211-226o13.3            0.000000      0.000000  0.000000
#
# [27538 rows x 41 columns]

# %%
collist = []
for name in df.columns:
    collist.append(name + "_spec")
collist
# Out:
# ['Cardiomyocyte_spec',
#  'Endothelial cell_spec',
#  'Enterocyte_spec',
#  'Epithelial cell_spec',
#  'Epithelial cell (Brain)_spec',
#  'Erythrocyte_spec',
#  'Erythrocyte (Liver)_spec',
#  'Erythroid Progenitor cell_spec',
#  'Fibroblast_spec',
#  'Goblet cell_spec',
#  'Granulocyte_spec',
#  'Granulosa cell_spec',
#  'Hatching Gland_spec',
#  'Hepatocyte_spec',
#  'Immune cell_spec',
#  'Immune Progenitor cell_spec',
#  'Intestinal Bulb cell_spec',
#  'Ionocyte_spec',
#  'Keratinocyte_spec',
#  'Macrophage_spec',
#  'Mesenchymal cell_spec',
#  'Mesenchymal cell (Caudal Fin)_spec',
#  'Mt-rich cell_spec',
#  'Muscle cell_spec',
#  'Nephron cell_spec',
#  'Neural cell_spec',
#  'Neural Progenitor cell_spec',
#  'Neurosecretory cell_spec',
#  'Oligodendrocyte_spec',
#  'Oocyte_spec',
#  'Osteoblast_spec',
#  'Pancreatic cell_spec',
#  'Pancreatic Macrophage_spec',
#  'Primordial Germ cell_spec',
#  'Radial Glia_spec',
#  'Retinal cell_spec',
#  'Retinal Cone cell_spec',
#  'Retinal Pigment Epithelial cell_spec',
#  'Smooth Muscle cell_spec',
#  'Spermatocyte_spec',
#  'T cell_spec']

# %%
df_spec = pd.DataFrame(columns=collist)
df_spec
# Out:
# Empty DataFrame
# Columns: [Cardiomyocyte_spec, Endothelial cell_spec, Enterocyte_spec, Epithelial cell_spec, Epithelial cell (Brain)_spec, Erythrocyte_spec, Erythrocyte (Liver)_spec, Erythroid Progenitor cell_spec, Fibroblast_spec, Goblet cell_spec, Granulocyte_spec, Granulosa cell_spec, Hatching Gland_spec, Hepatocyte_spec, Immune cell_spec, Immune Progenitor cell_spec, Intestinal Bulb cell_spec, Ionocyte_spec, Keratinocyte_spec, Macrophage_spec, Mesenchymal cell_spec, Mesenchymal cell (Caudal Fin)_spec, Mt-rich cell_spec, Muscle cell_spec, Nephron cell_spec, Neural cell_spec, Neural Progenitor cell_spec, Neurosecretory cell_spec, Oligodendrocyte_spec, Oocyte_spec, Osteoblast_spec, Pancreatic cell_spec, Pancreatic Macrophage_spec, Primordial Germ cell_spec, Radial Glia_spec, Retinal cell_spec, Retinal Cone cell_spec, Retinal Pigment Epithelial cell_spec, Smooth Muscle cell_spec, Spermatocyte_spec, T cell_spec]
# Index: []
#
# [0 rows x 41 columns]

# %%
for column in df.columns:
    max = df.drop(column, axis=1).max(axis=1)
    df_spec[column + "_spec"] = 1 - max
df_spec
# Out:
#                    Cardiomyocyte_spec  Endothelial cell_spec  Enterocyte_spec  \
# gene
# ABCF3                        0.950111               0.950111         0.950111
# ACSF3                        0.959408               0.959408         0.959408
# ACTC1                        0.992188               0.865224         0.865224
# ADAM12                       0.998155               0.998155         0.998155
# ADAMTSL4                     0.985210               0.985210         0.985210
# ...                               ...                    ...              ...
# CR478208.1                   0.999955               0.999955         0.999955
# CU469530.2                   0.999988               0.999988         0.999988
# BX119915.3                   1.000000               1.000000         1.000000
# pimr161                      0.999955               0.999955         0.999955
# si:ch211-226o13.3            1.000000               1.000000         1.000000
#
#                    Epithelial cell_spec  Epithelial cell (Brain)_spec  \
# gene
# ABCF3                          0.950111                      0.950111
# ACSF3                          0.959408                      0.959408
# ACTC1                          0.865224                      0.865224
# ADAM12                         0.998155                      0.998155
# ADAMTSL4                       0.985210                      0.985210
# ...                                 ...                           ...
# CR478208.1                     0.999955                      0.999955
# CU469530.2                     0.999988                      0.999988
# BX119915.3                     1.000000                      1.000000
# pimr161                        0.999955                      0.999955
# si:ch211-226o13.3              1.000000                      1.000000
#
#                    Erythrocyte_spec  Erythrocyte (Liver)_spec  \
# gene
# ABCF3                      0.950111                  0.950111
# ACSF3                      0.959408                  0.959408
# ACTC1                      0.865224                  0.865224
# ADAM12                     0.998155                  0.998155
# ADAMTSL4                   0.985210                  0.985210
# ...                             ...                       ...
# CR478208.1                 0.999955                  0.999955
# CU469530.2                 0.999988                  0.999988
# BX119915.3                 1.000000                  1.000000
# pimr161                    0.999955                  0.999955
# si:ch211-226o13.3          1.000000                  1.000000
#
#                    Erythroid Progenitor cell_spec  Fibroblast_spec  \
# gene
# ABCF3                                    0.950111         0.950111
# ACSF3                                    0.959408         0.959408
# ACTC1                                    0.865224         0.865224
# ADAM12                                   0.998155         0.998155
# ADAMTSL4                                 0.985210         0.985210
# ...                                           ...              ...
# CR478208.1                               0.999955         0.999955
# CU469530.2                               0.999988         0.999988
# BX119915.3                               1.000000         1.000000
# pimr161                                  0.999955         0.999955
# si:ch211-226o13.3                        1.000000         1.000000
#
#                    Goblet cell_spec  ...  Pancreatic cell_spec  \
# gene                                 ...
# ABCF3                      0.950111  ...              0.950111
# ACSF3                      0.959408  ...              0.959408
# ACTC1                      0.865224  ...              0.865224
# ADAM12                     0.998155  ...              0.998155
# ADAMTSL4                   0.985210  ...              0.985210
# ...                             ...  ...                   ...
# CR478208.1                 0.999955  ...              0.999955
# CU469530.2                 0.999988  ...              0.999988
# BX119915.3                 1.000000  ...              1.000000
# pimr161                    0.999955  ...              0.999955
# si:ch211-226o13.3          1.000000  ...              1.000000
#
#                    Pancreatic Macrophage_spec  Primordial Germ cell_spec  \
# gene
# ABCF3                                0.950111                   0.957430
# ACSF3                                0.959408                   0.959408
# ACTC1                                0.865224                   0.865224
# ADAM12                               0.998155                   0.998155
# ADAMTSL4                             0.985210                   0.985210
# ...                                       ...                        ...
# CR478208.1                           0.999955                   0.999955
# CU469530.2                           0.999988                   0.999988
# BX119915.3                           1.000000                   1.000000
# pimr161                              0.999955                   0.999955
# si:ch211-226o13.3                    1.000000                   1.000000
#
#                    Radial Glia_spec  Retinal cell_spec  \
# gene
# ABCF3                      0.950111           0.950111
# ACSF3                      0.959408           0.959408
# ACTC1                      0.865224           0.865224
# ADAM12                     0.998155           0.998155
# ADAMTSL4                   0.985210           0.985210
# ...                             ...                ...
# CR478208.1                 0.999955           0.999955
# CU469530.2                 0.999988           0.999988
# BX119915.3                 1.000000           1.000000
# pimr161                    0.999955           0.999955
# si:ch211-226o13.3          1.000000           1.000000
#
#                    Retinal Cone cell_spec  \
# gene
# ABCF3                            0.950111
# ACSF3                            0.959408
# ACTC1                            0.865224
# ADAM12                           0.998155
# ADAMTSL4                         0.985210
# ...                                   ...
# CR478208.1                       0.999955
# CU469530.2                       0.999988
# BX119915.3                       1.000000
# pimr161                          0.999955
# si:ch211-226o13.3                1.000000
#
#                    Retinal Pigment Epithelial cell_spec  \
# gene
# ABCF3                                          0.950111
# ACSF3                                          0.959408
# ACTC1                                          0.865224
# ADAM12                                         0.998297
# ADAMTSL4                                       0.985210
# ...                                                 ...
# CR478208.1                                     0.999955
# CU469530.2                                     0.999988
# BX119915.3                                     1.000000
# pimr161                                        0.999955
# si:ch211-226o13.3                              1.000000
#
#                    Smooth Muscle cell_spec  Spermatocyte_spec  T cell_spec
# gene
# ABCF3                             0.950111           0.950111     0.950111
# ACSF3                             0.959408           0.959408     0.959408
# ACTC1                             0.865224           0.865224     0.865224
# ADAM12                            0.998155           0.998155     0.998155
# ADAMTSL4                          0.985210           0.985210     0.985210
# ...                                    ...                ...          ...
# CR478208.1                        0.999955           0.999955     0.999955
# CU469530.2                        0.999988           0.999988     0.999988
# BX119915.3                        1.000000           1.000000     1.000000
# pimr161                           0.999955           0.999955     0.999955
# si:ch211-226o13.3                 1.000000           1.000000     1.000000
#
# [27538 rows x 41 columns]

# %%
df_spec.to_csv("Landscape_spec.csv")

# %%
#test an api call
tissue = "Cardiomyocyte"
weight = 90
number = 50
percent =  weight / 100
cov = df[tissue]
spec = df_spec[tissue + "_spec"]
cov_weighted = df[tissue] * percent
spec_weighted = df_spec[tissue + "_spec"] * (1 - percent)

sum = cov + spec

sum = sum.sort_values(ascending=False)

list = []
for gene in sum.iloc[:number].index:
    list.append({"data": gene, "x": cov[gene], "y": spec[gene]})
list
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\drago\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\drago\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\drago\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cardiomyocyte'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\drago\OneDrive\Documents\zebrafish website\dataprep landscape.ipynb Cell 8 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/drago/OneDrive/Documents/zebrafish%20website/dataprep%20landscape.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> number = 50
#       <a href='vscode-notebook-cell:/c%3A/Users/drago/OneDrive/Documents/zebrafish%20website/dataprep%20landscape.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> percent =  weight / 100
# ----> <a href='vscode-notebook-cell:/c%3A/Users/drago/OneDrive/Documents/zebrafish%20website/dataprep%20landscape.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> cov = df[tissue]
#       <a href='vscode-notebook-cell:/c%3A/Users/drago/OneDrive/Documents/zebrafish%20website/dataprep%20landscape.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> spec = df_spec[tissue + "_spec"]
#       <a href='vscode-notebook-cell:/c%3A/Users/drago/OneDrive/Documents/zebrafish%20website/dataprep%20landscape.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> cov_weighted = df[tissue] * percent
#
# File c:\Users\drago\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\drago\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Cardiomyocyte'

# %%
df.loc["zgc:158463",]
# Out:
# Amacrine       1.000000
# Bipolar        1.000000
# Cone           0.999671
# Cornea         1.000000
# Horizontal     0.999592
# Müller Glia    1.000000
# RGC            1.000000
# Rod            1.000000
# RPE            1.000000
# Name: zgc:158463, dtype: float64
