# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Landscape72hr.csv")
df = df.iloc[:, :-2]

df
# Out:
#               Unnamed: 0  Cardiomyocyte  Endothelial cell  Epithelial cell  \
# 0                  ABCF3       0.020251          0.013047         0.012481
# 1                  ACSF3       0.009997          0.006140         0.006144
# 2                  ACTC1       0.209177          0.000767         0.001344
# 3                 ADAM12       0.001282          0.000000         0.000192
# 4               ADAMTSL4       0.000256          0.002302         0.000384
# ...                  ...            ...               ...              ...
# 27533         CR478208.1       0.000000          0.000000         0.000000
# 27534         CU469530.2       0.000000          0.000000         0.000000
# 27535         BX119915.3       0.000000          0.000000         0.000000
# 27536            pimr161       0.000000          0.000000         0.000000
# 27537  si:ch211-226o13.3       0.000000          0.000000         0.000000
#
#        Epithelial cell (Brain)  Erythrocyte  Erythroid Progenitor cell  \
# 0                     0.017576     0.004248                   0.046875
# 1                     0.007401     0.001821                   0.010417
# 2                     0.002775     0.001972                   0.005208
# 3                     0.001850     0.000303                   0.000000
# 4                     0.000000     0.000152                   0.000000
# ...                        ...          ...                        ...
# 27533                 0.000000     0.000000                   0.000000
# 27534                 0.000000     0.000000                   0.000000
# 27535                 0.000000     0.000000                   0.000000
# 27536                 0.000000     0.000000                   0.000000
# 27537                 0.000000     0.000000                   0.000000
#
#        Granulocyte  Hepatocyte  Immune Progenitor cell  ...  \
# 0         0.012346     0.01087                0.041899  ...
# 1         0.006173     0.01087                0.011173  ...
# 2         0.000000     0.00000                0.000000  ...
# 3         0.000000     0.00000                0.000000  ...
# 4         0.000000     0.00000                0.005587  ...
# ...            ...         ...                     ...  ...
# 27533     0.000000     0.00000                0.000000  ...
# 27534     0.000000     0.00000                0.000000  ...
# 27535     0.000000     0.00000                0.000000  ...
# 27536     0.000000     0.00000                0.000000  ...
# 27537     0.000000     0.00000                0.000000  ...
#
#        Neural Progenitor cell  Neurosecretory cell  Oligodendrocyte  \
# 0                    0.016963             0.003968         0.023061
# 1                    0.006285             0.011905         0.006289
# 2                    0.001732             0.000000         0.002096
# 3                    0.000192             0.000000         0.002096
# 4                    0.000353             0.000000         0.000000
# ...                       ...                  ...              ...
# 27533                0.000000             0.000000         0.000000
# 27534                0.000000             0.000000         0.000000
# 27535                0.000000             0.000000         0.000000
# 27536                0.000000             0.000000         0.000000
# 27537                0.000000             0.000000         0.000000
#
#        Osteoblast  Pancreatic cell  Primordial Germ cell  Radial Glia  \
# 0        0.011703         0.052863              0.125000     0.011719
# 1        0.004520         0.013216              0.041667     0.005859
# 2        0.001211         0.000000              0.000000     0.001302
# 3        0.001211         0.000000              0.000000     0.000000
# 4        0.002663         0.000000              0.000000     0.001085
# ...           ...              ...                   ...          ...
# 27533    0.000000         0.000000              0.000000     0.000000
# 27534    0.000000         0.000000              0.000000     0.000000
# 27535    0.000000         0.000000              0.000000     0.000000
# 27536    0.000000         0.000000              0.000000     0.000000
# 27537    0.000000         0.000000              0.000000     0.000000
#
#        Retinal cell  Retinal Cone cell  Retinal Pigment Epithelial cell
# 0          0.029674           0.015094                         0.027180
# 1          0.014837           0.003774                         0.002265
# 2          0.002967           0.007547                         0.002265
# 3          0.000000           0.000000                         0.001133
# 4          0.000000           0.000000                         0.002265
# ...             ...                ...                              ...
# 27533      0.000000           0.000000                         0.000000
# 27534      0.000000           0.000000                         0.000000
# 27535      0.000000           0.000000                         0.000000
# 27536      0.000000           0.000000                         0.000000
# 27537      0.000000           0.000000                         0.000000
#
# [27538 rows x 29 columns]

# %%
df = df.set_index("Unnamed: 0")
df.to_csv("Landscape72hr.truncated.csv")
df
# Out:
#                    Cardiomyocyte  Endothelial cell  Epithelial cell  \
# Unnamed: 0
# ABCF3                   0.020251          0.013047         0.012481
# ACSF3                   0.009997          0.006140         0.006144
# ACTC1                   0.209177          0.000767         0.001344
# ADAM12                  0.001282          0.000000         0.000192
# ADAMTSL4                0.000256          0.002302         0.000384
# ...                          ...               ...              ...
# CR478208.1              0.000000          0.000000         0.000000
# CU469530.2              0.000000          0.000000         0.000000
# BX119915.3              0.000000          0.000000         0.000000
# pimr161                 0.000000          0.000000         0.000000
# si:ch211-226o13.3       0.000000          0.000000         0.000000
#
#                    Epithelial cell (Brain)  Erythrocyte  \
# Unnamed: 0
# ABCF3                             0.017576     0.004248
# ACSF3                             0.007401     0.001821
# ACTC1                             0.002775     0.001972
# ADAM12                            0.001850     0.000303
# ADAMTSL4                          0.000000     0.000152
# ...                                    ...          ...
# CR478208.1                        0.000000     0.000000
# CU469530.2                        0.000000     0.000000
# BX119915.3                        0.000000     0.000000
# pimr161                           0.000000     0.000000
# si:ch211-226o13.3                 0.000000     0.000000
#
#                    Erythroid Progenitor cell  Granulocyte  Hepatocyte  \
# Unnamed: 0
# ABCF3                               0.046875     0.012346     0.01087
# ACSF3                               0.010417     0.006173     0.01087
# ACTC1                               0.005208     0.000000     0.00000
# ADAM12                              0.000000     0.000000     0.00000
# ADAMTSL4                            0.000000     0.000000     0.00000
# ...                                      ...          ...         ...
# CR478208.1                          0.000000     0.000000     0.00000
# CU469530.2                          0.000000     0.000000     0.00000
# BX119915.3                          0.000000     0.000000     0.00000
# pimr161                             0.000000     0.000000     0.00000
# si:ch211-226o13.3                   0.000000     0.000000     0.00000
#
#                    Immune Progenitor cell  Intestinal Bulb cell  ...  \
# Unnamed: 0                                                       ...
# ABCF3                            0.041899                   0.0  ...
# ACSF3                            0.011173                   0.0  ...
# ACTC1                            0.000000                   0.0  ...
# ADAM12                           0.000000                   0.0  ...
# ADAMTSL4                         0.005587                   0.0  ...
# ...                                   ...                   ...  ...
# CR478208.1                       0.000000                   0.0  ...
# CU469530.2                       0.000000                   0.0  ...
# BX119915.3                       0.000000                   0.0  ...
# pimr161                          0.000000                   0.0  ...
# si:ch211-226o13.3                0.000000                   0.0  ...
#
#                    Neural Progenitor cell  Neurosecretory cell  \
# Unnamed: 0
# ABCF3                            0.016963             0.003968
# ACSF3                            0.006285             0.011905
# ACTC1                            0.001732             0.000000
# ADAM12                           0.000192             0.000000
# ADAMTSL4                         0.000353             0.000000
# ...                                   ...                  ...
# CR478208.1                       0.000000             0.000000
# CU469530.2                       0.000000             0.000000
# BX119915.3                       0.000000             0.000000
# pimr161                          0.000000             0.000000
# si:ch211-226o13.3                0.000000             0.000000
#
#                    Oligodendrocyte  Osteoblast  Pancreatic cell  \
# Unnamed: 0
# ABCF3                     0.023061    0.011703         0.052863
# ACSF3                     0.006289    0.004520         0.013216
# ACTC1                     0.002096    0.001211         0.000000
# ADAM12                    0.002096    0.001211         0.000000
# ADAMTSL4                  0.000000    0.002663         0.000000
# ...                            ...         ...              ...
# CR478208.1                0.000000    0.000000         0.000000
# CU469530.2                0.000000    0.000000         0.000000
# BX119915.3                0.000000    0.000000         0.000000
# pimr161                   0.000000    0.000000         0.000000
# si:ch211-226o13.3         0.000000    0.000000         0.000000
#
#                    Primordial Germ cell  Radial Glia  Retinal cell  \
# Unnamed: 0
# ABCF3                          0.125000     0.011719      0.029674
# ACSF3                          0.041667     0.005859      0.014837
# ACTC1                          0.000000     0.001302      0.002967
# ADAM12                         0.000000     0.000000      0.000000
# ADAMTSL4                       0.000000     0.001085      0.000000
# ...                                 ...          ...           ...
# CR478208.1                     0.000000     0.000000      0.000000
# CU469530.2                     0.000000     0.000000      0.000000
# BX119915.3                     0.000000     0.000000      0.000000
# pimr161                        0.000000     0.000000      0.000000
# si:ch211-226o13.3              0.000000     0.000000      0.000000
#
#                    Retinal Cone cell  Retinal Pigment Epithelial cell
# Unnamed: 0
# ABCF3                       0.015094                         0.027180
# ACSF3                       0.003774                         0.002265
# ACTC1                       0.007547                         0.002265
# ADAM12                      0.000000                         0.001133
# ADAMTSL4                    0.000000                         0.002265
# ...                              ...                              ...
# CR478208.1                  0.000000                         0.000000
# CU469530.2                  0.000000                         0.000000
# BX119915.3                  0.000000                         0.000000
# pimr161                     0.000000                         0.000000
# si:ch211-226o13.3           0.000000                         0.000000
#
# [27538 rows x 28 columns]

# %%
collist = []
for name in df.columns:
    collist.append(name + "_spec")
collist
# Out:
# ['Cardiomyocyte_spec',
#  'Endothelial cell_spec',
#  'Epithelial cell_spec',
#  'Epithelial cell (Brain)_spec',
#  'Erythrocyte_spec',
#  'Erythroid Progenitor cell_spec',
#  'Granulocyte_spec',
#  'Hepatocyte_spec',
#  'Immune Progenitor cell_spec',
#  'Intestinal Bulb cell_spec',
#  'Ionocyte_spec',
#  'Keratinocyte_spec',
#  'Macrophage_spec',
#  'Mesenchymal cell_spec',
#  'Mt-rich cell_spec',
#  'Muscle cell_spec',
#  'Nephron cell_spec',
#  'Neural cell_spec',
#  'Neural Progenitor cell_spec',
#  'Neurosecretory cell_spec',
#  'Oligodendrocyte_spec',
#  'Osteoblast_spec',
#  'Pancreatic cell_spec',
#  'Primordial Germ cell_spec',
#  'Radial Glia_spec',
#  'Retinal cell_spec',
#  'Retinal Cone cell_spec',
#  'Retinal Pigment Epithelial cell_spec']

# %%
df_spec = pd.DataFrame(columns=collist)
df_spec
# Out:
# Empty DataFrame
# Columns: [Cardiomyocyte_spec, Endothelial cell_spec, Epithelial cell_spec, Epithelial cell (Brain)_spec, Erythrocyte_spec, Erythroid Progenitor cell_spec, Granulocyte_spec, Hepatocyte_spec, Immune Progenitor cell_spec, Intestinal Bulb cell_spec, Ionocyte_spec, Keratinocyte_spec, Macrophage_spec, Mesenchymal cell_spec, Mt-rich cell_spec, Muscle cell_spec, Nephron cell_spec, Neural cell_spec, Neural Progenitor cell_spec, Neurosecretory cell_spec, Oligodendrocyte_spec, Osteoblast_spec, Pancreatic cell_spec, Primordial Germ cell_spec, Radial Glia_spec, Retinal cell_spec, Retinal Cone cell_spec, Retinal Pigment Epithelial cell_spec]
# Index: []
#
# [0 rows x 28 columns]

# %%
for column in df.columns:
    max = df.drop(column, axis=1).max(axis=1)
    df_spec[column + "_spec"] = 1 - max
df_spec
# Out:
#                    Cardiomyocyte_spec  Endothelial cell_spec  \
# Unnamed: 0
# ABCF3                        0.875000               0.875000
# ACSF3                        0.950276               0.950276
# ACTC1                        0.950617               0.790823
# ADAM12                       0.997531               0.997531
# ADAMTSL4                     0.982867               0.982867
# ...                               ...                    ...
# CR478208.1                   1.000000               1.000000
# CU469530.2                   1.000000               1.000000
# BX119915.3                   1.000000               1.000000
# pimr161                      1.000000               1.000000
# si:ch211-226o13.3            1.000000               1.000000
#
#                    Epithelial cell_spec  Epithelial cell (Brain)_spec  \
# Unnamed: 0
# ABCF3                          0.875000                      0.875000
# ACSF3                          0.950276                      0.950276
# ACTC1                          0.790823                      0.790823
# ADAM12                         0.997531                      0.997531
# ADAMTSL4                       0.982867                      0.982867
# ...                                 ...                           ...
# CR478208.1                     1.000000                      1.000000
# CU469530.2                     1.000000                      1.000000
# BX119915.3                     1.000000                      1.000000
# pimr161                        1.000000                      1.000000
# si:ch211-226o13.3              1.000000                      1.000000
#
#                    Erythrocyte_spec  Erythroid Progenitor cell_spec  \
# Unnamed: 0
# ABCF3                      0.875000                        0.875000
# ACSF3                      0.950276                        0.950276
# ACTC1                      0.790823                        0.790823
# ADAM12                     0.997531                        0.997531
# ADAMTSL4                   0.982867                        0.982867
# ...                             ...                             ...
# CR478208.1                 1.000000                        1.000000
# CU469530.2                 1.000000                        1.000000
# BX119915.3                 1.000000                        1.000000
# pimr161                    1.000000                        1.000000
# si:ch211-226o13.3          1.000000                        1.000000
#
#                    Granulocyte_spec  Hepatocyte_spec  \
# Unnamed: 0
# ABCF3                      0.875000         0.875000
# ACSF3                      0.950276         0.950276
# ACTC1                      0.790823         0.790823
# ADAM12                     0.997531         0.997531
# ADAMTSL4                   0.982867         0.982867
# ...                             ...              ...
# CR478208.1                 1.000000         1.000000
# CU469530.2                 1.000000         1.000000
# BX119915.3                 1.000000         1.000000
# pimr161                    1.000000         1.000000
# si:ch211-226o13.3          1.000000         1.000000
#
#                    Immune Progenitor cell_spec  Intestinal Bulb cell_spec  \
# Unnamed: 0
# ABCF3                                 0.875000                   0.875000
# ACSF3                                 0.950276                   0.950276
# ACTC1                                 0.790823                   0.790823
# ADAM12                                0.997531                   0.997531
# ADAMTSL4                              0.982867                   0.982867
# ...                                        ...                        ...
# CR478208.1                            1.000000                   1.000000
# CU469530.2                            1.000000                   1.000000
# BX119915.3                            1.000000                   1.000000
# pimr161                               1.000000                   1.000000
# si:ch211-226o13.3                     1.000000                   1.000000
#
#                    ...  Neural Progenitor cell_spec  Neurosecretory cell_spec  \
# Unnamed: 0         ...
# ABCF3              ...                     0.875000                  0.875000
# ACSF3              ...                     0.950276                  0.950276
# ACTC1              ...                     0.790823                  0.790823
# ADAM12             ...                     0.997531                  0.997531
# ADAMTSL4           ...                     0.982867                  0.982867
# ...                ...                          ...                       ...
# CR478208.1         ...                     1.000000                  1.000000
# CU469530.2         ...                     1.000000                  1.000000
# BX119915.3         ...                     1.000000                  1.000000
# pimr161            ...                     1.000000                  1.000000
# si:ch211-226o13.3  ...                     1.000000                  1.000000
#
#                    Oligodendrocyte_spec  Osteoblast_spec  \
# Unnamed: 0
# ABCF3                          0.875000         0.875000
# ACSF3                          0.950276         0.950276
# ACTC1                          0.790823         0.790823
# ADAM12                         0.997531         0.997531
# ADAMTSL4                       0.982867         0.982867
# ...                                 ...              ...
# CR478208.1                     1.000000         1.000000
# CU469530.2                     1.000000         1.000000
# BX119915.3                     1.000000         1.000000
# pimr161                        1.000000         1.000000
# si:ch211-226o13.3              1.000000         1.000000
#
#                    Pancreatic cell_spec  Primordial Germ cell_spec  \
# Unnamed: 0
# ABCF3                          0.875000                   0.947137
# ACSF3                          0.950276                   0.950276
# ACTC1                          0.790823                   0.790823
# ADAM12                         0.997531                   0.997531
# ADAMTSL4                       0.982867                   0.982867
# ...                                 ...                        ...
# CR478208.1                     1.000000                   1.000000
# CU469530.2                     1.000000                   1.000000
# BX119915.3                     1.000000                   1.000000
# pimr161                        1.000000                   1.000000
# si:ch211-226o13.3              1.000000                   1.000000
#
#                    Radial Glia_spec  Retinal cell_spec  \
# Unnamed: 0
# ABCF3                      0.875000           0.875000
# ACSF3                      0.950276           0.950276
# ACTC1                      0.790823           0.790823
# ADAM12                     0.997531           0.997531
# ADAMTSL4                   0.982867           0.982867
# ...                             ...                ...
# CR478208.1                 1.000000           1.000000
# CU469530.2                 1.000000           1.000000
# BX119915.3                 1.000000           1.000000
# pimr161                    1.000000           1.000000
# si:ch211-226o13.3          1.000000           1.000000
#
#                    Retinal Cone cell_spec  \
# Unnamed: 0
# ABCF3                            0.875000
# ACSF3                            0.950276
# ACTC1                            0.790823
# ADAM12                           0.997531
# ADAMTSL4                         0.982867
# ...                                   ...
# CR478208.1                       1.000000
# CU469530.2                       1.000000
# BX119915.3                       1.000000
# pimr161                          1.000000
# si:ch211-226o13.3                1.000000
#
#                    Retinal Pigment Epithelial cell_spec
# Unnamed: 0
# ABCF3                                          0.875000
# ACSF3                                          0.950276
# ACTC1                                          0.790823
# ADAM12                                         0.997531
# ADAMTSL4                                       0.982867
# ...                                                 ...
# CR478208.1                                     1.000000
# CU469530.2                                     1.000000
# BX119915.3                                     1.000000
# pimr161                                        1.000000
# si:ch211-226o13.3                              1.000000
#
# [27538 rows x 28 columns]

# %%
df_spec.to_csv("Landscape72hr_spec.csv")

# %%
#test an api call
tissue = "Cardiomyocyte"
weight = 90
number = 50
percent =  weight / 100
cov = df[tissue]
spec = df_spec[tissue + "_spec"]
cov_weighted = df[tissue] * percent
spec_weighted = df_spec[tissue + "_spec"] * (1 - percent)

sum = cov + spec

sum = sum.sort_values(ascending=False)

list = []
for gene in sum.iloc[:number].index:
    list.append({"data": gene, "x": cov[gene], "y": spec[gene]})
list
# Out:
# [{'data': 'si:ch211-226o13.3', 'x': 0.0, 'y': 1.0},
#  {'data': 'dre-mir-18a', 'x': 0.0, 'y': 1.0},
#  {'data': 'si:dkey-199k11.6', 'x': 0.0, 'y': 1.0},
#  {'data': 'si:dkeyp-77c8.5', 'x': 0.000183368, 'y': 0.999816632},
#  {'data': 'BX323555.2', 'x': 0.0, 'y': 1.0},
#  {'data': 'BX649639.1', 'x': 0.000183368, 'y': 0.999816632},
#  {'data': 'cavin4b', 'x': 0.104061612, 'y': 0.895938388},
#  {'data': 'cavin4a', 'x': 0.140001834, 'y': 0.859998166},
#  {'data': 'cavin1a', 'x': 0.035481801, 'y': 0.964518199},
#  {'data': 'cav3', 'x': 0.169524159, 'y': 0.8304758409999999},
#  {'data': 'CABZ01042417.1', 'x': 9.17e-05, 'y': 0.9999083},
#  {'data': 'CABZ01078663.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'CABZ01101739.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'casq2', 'x': 0.145961309, 'y': 0.854038691},
#  {'data': 'casq1b', 'x': 0.065554231, 'y': 0.934445769},
#  {'data': 'casq1a', 'x': 0.079123499, 'y': 0.920876501},
#  {'data': 'CR456635.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'CR759791.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'CU693440.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'CU695077.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'dre-mir-218a-2', 'x': 9.17e-05, 'y': 0.9999083},
#  {'data': 'cap2', 'x': 0.087833501, 'y': 0.912166499},
#  {'data': 'si:dkeyp-104f11.8', 'x': 9.17e-05, 'y': 0.9999083},
#  {'data': 'BX255897.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'BX323543.3', 'x': 0.0, 'y': 1.0},
#  {'data': 'BX649610.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'BX927288.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'cacng4a', 'x': 0.007884845, 'y': 0.992115155},
#  {'data': 'cacng1a', 'x': 0.087466764, 'y': 0.912533236},
#  {'data': 'CT573048.1', 'x': 9.17e-05, 'y': 0.9999083},
#  {'data': 'cacna1sb', 'x': 0.019528743, 'y': 0.980471257},
#  {'data': 'si:dkey-157e10.8', 'x': 0.0, 'y': 1.0},
#  {'data': 'pimr6', 'x': 0.0, 'y': 1.0},
#  {'data': 'dre-mir-365-2', 'x': 9.17e-05, 'y': 0.9999083},
#  {'data': 'CR626935.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'BX649471.2', 'x': 9.17e-05, 'y': 0.9999083},
#  {'data': 'CR678435.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'CR847973.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'CT027589.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'cdh15', 'x': 0.020628954, 'y': 0.979371046},
#  {'data': 'CT033825.1', 'x': 0.000366737, 'y': 0.999633263},
#  {'data': 'CU861501.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'si:dkey-14o6.4', 'x': 9.17e-05, 'y': 0.9999083},
#  {'data': 'si:dkey-23a13.12', 'x': 0.0, 'y': 1.0},
#  {'data': 'si:dkeyp-77c8.2', 'x': 0.0, 'y': 1.0},
#  {'data': 'tradv6.0.4', 'x': 0.0, 'y': 1.0},
#  {'data': 'BX649295.2', 'x': 9.17e-05, 'y': 0.9999083},
#  {'data': 'BX936421.1', 'x': 0.0, 'y': 1.0},
#  {'data': 'CR786578.1', 'x': 9.17e-05, 'y': 0.9999083},
#  {'data': 'dre-mir-10b-2', 'x': 9.17e-05, 'y': 0.9999083}]

# %%
df.loc["zgc:158463",]
# Out:
# Amacrine       1.000000
# Bipolar        1.000000
# Cone           0.999671
# Cornea         1.000000
# Horizontal     0.999592
# Müller Glia    1.000000
# RGC            1.000000
# Rod            1.000000
# RPE            1.000000
# Name: zgc:158463, dtype: float64
