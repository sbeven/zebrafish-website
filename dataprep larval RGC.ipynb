# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Larval_RGC.gene.expr.csv")
df = df.iloc[:, :-2]
df
# Out:
#       Unnamed: 0  cluster.1  cluster.2  cluster.3  cluster.4  cluster.5  \
# 0           SYN3   0.001041   0.000000   0.000000   0.000000   0.000000
# 1          PTPRO   0.234131   0.253536   0.231803   0.098701   0.242816
# 2           EPS8   0.004162   0.004353   0.002240   0.006494   0.002874
# 3           TBK1   0.081165   0.079434   0.090705   0.093506   0.076149
# 4          GPR19   0.028096   0.039173   0.030235   0.042857   0.015805
# ...          ...        ...        ...        ...        ...        ...
# 24100     ZNF985   0.005203   0.009793   0.007839   0.003896   0.007184
# 24101     ZNF987   0.001041   0.000000   0.001120   0.000000   0.000000
# 24102     ZNF993   0.001041   0.001088   0.000000   0.000000   0.000000
# 24103     ZNF995   0.003122   0.003264   0.007839   0.002597   0.008621
# 24104        ZP2   0.000000   0.000000   0.000000   0.000000   0.000000
#
#        cluster.6  cluster.7  cluster.8  cluster.9  ...  cluster.20  \
# 0       0.000000   0.000000   0.000000   0.000000  ...    0.000000
# 1       0.047359   0.129870   0.116466   0.092379  ...    0.191729
# 2       0.007286   0.005566   0.034137   0.011547  ...    0.007519
# 3       0.102004   0.074212   0.116466   0.133949  ...    0.063910
# 4       0.030965   0.031540   0.066265   0.025404  ...    0.015038
# ...          ...        ...        ...        ...  ...         ...
# 24100   0.001821   0.012987   0.000000   0.002309  ...    0.007519
# 24101   0.000000   0.000000   0.000000   0.000000  ...    0.000000
# 24102   0.000000   0.000000   0.000000   0.000000  ...    0.000000
# 24103   0.001821   0.003711   0.002008   0.000000  ...    0.000000
# 24104   0.000000   0.000000   0.000000   0.000000  ...    0.000000
#
#        cluster.21  cluster.22  cluster.23  cluster.24  cluster.25  cluster.26  \
# 0        0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 1        0.113208    0.222656    0.164251    0.047904    0.093168    0.121212
# 2        0.007547    0.003906    0.000000    0.005988    0.031056    0.000000
# 3        0.079245    0.140625    0.072464    0.113772    0.080745    0.141414
# 4        0.007547    0.046875    0.024155    0.029940    0.055901    0.050505
# ...           ...         ...         ...         ...         ...         ...
# 24100    0.003774    0.011719    0.014493    0.011976    0.000000    0.000000
# 24101    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 24102    0.000000    0.000000    0.000000    0.005988    0.000000    0.000000
# 24103    0.000000    0.000000    0.004831    0.005988    0.000000    0.000000
# 24104    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
#
#        cluster.27  cluster.28  cluster.29
# 0        0.000000    0.000000    0.000000
# 1        0.061856    0.081633    0.135135
# 2        0.000000    0.040816    0.027027
# 3        0.092784    0.081633    0.189189
# 4        0.010309    0.081633    0.000000
# ...           ...         ...         ...
# 24100    0.000000    0.000000    0.000000
# 24101    0.000000    0.000000    0.000000
# 24102    0.000000    0.000000    0.000000
# 24103    0.000000    0.000000    0.000000
# 24104    0.000000    0.000000    0.000000
#
# [24105 rows x 30 columns]

# %%
df = df.set_index("Unnamed: 0")
df.to_csv("Larval_RGC.gene.expr.csv")
df
# Out:
#             cluster.1  cluster.2  cluster.3  cluster.4  cluster.5  cluster.6  \
# Unnamed: 0
    collist.append(name + "_spec")
collist
# Out:
# ['cluster.1_spec',
#  'cluster.2_spec',
#  'cluster.3_spec',
#  'cluster.4_spec',
#  'cluster.5_spec',
#  'cluster.6_spec',
#  'cluster.7_spec',
#  'cluster.8_spec',
#  'cluster.9_spec',
#  'cluster.10_spec',
#  'cluster.11_spec',
#  'cluster.12_spec',
#  'cluster.13_spec',
#  'cluster.14_spec',
#  'cluster.15_spec',
#  'cluster.16_spec',
#  'cluster.17_spec',
#  'cluster.18_spec',
#  'cluster.19_spec',
#  'cluster.20_spec',
#  'cluster.21_spec',
#  'cluster.22_spec',
#  'cluster.23_spec',
#  'cluster.24_spec',
#  'cluster.25_spec',
#  'cluster.26_spec',
#  'cluster.27_spec',
#  'cluster.28_spec',
#  'cluster.29_spec']

# %%
df_spec = pd.DataFrame(columns=collist)
df_spec
# Out:
# Empty DataFrame
# Columns: [cluster.1_spec, cluster.2_spec, cluster.3_spec, cluster.4_spec, cluster.5_spec, cluster.6_spec, cluster.7_spec, cluster.8_spec, cluster.9_spec, cluster.10_spec, cluster.11_spec, cluster.12_spec, cluster.13_spec, cluster.14_spec, cluster.15_spec, cluster.16_spec, cluster.17_spec, cluster.18_spec, cluster.19_spec, cluster.20_spec, cluster.21_spec, cluster.22_spec, cluster.23_spec, cluster.24_spec, cluster.25_spec, cluster.26_spec, cluster.27_spec, cluster.28_spec, cluster.29_spec]
# Index: []
#
# [0 rows x 29 columns]

# %%
for column in df.columns:
    max = df.drop(column, axis=1).max(axis=1)
    df_spec[column + "_spec"] = 1 - max
df_spec
# Out:
#             cluster.1_spec  cluster.2_spec  cluster.3_spec  cluster.4_spec  \
# Unnamed: 0
# SYN3              0.996942        0.996942        0.996942        0.996942
# PTPRO             0.746464        0.757184        0.746464        0.746464
# EPS8              0.934483        0.934483        0.934483        0.934483
# TBK1              0.810811        0.810811        0.810811        0.810811
# GPR19             0.918367        0.918367        0.918367        0.918367
# ...                    ...             ...             ...             ...
# ZNF985            0.985507        0.985507        0.985507        0.985507
# ZNF987            0.997680        0.997680        0.997680        0.997680
# ZNF993            0.994012        0.994012        0.994012        0.994012
# ZNF995            0.991379        0.991379        0.991379        0.991379
# ZP2               1.000000        1.000000        1.000000        1.000000
#
#             cluster.5_spec  cluster.6_spec  cluster.7_spec  cluster.8_spec  \
# Unnamed: 0
# SYN3              0.996942        0.996942        0.996942        0.996942
# PTPRO             0.746464        0.746464        0.746464        0.746464
# EPS8              0.934483        0.934483        0.934483        0.934483
# TBK1              0.810811        0.810811        0.810811        0.810811
# GPR19             0.918367        0.918367        0.918367        0.918367
# ...                    ...             ...             ...             ...
# ZNF985            0.985507        0.985507        0.985507        0.985507
# ZNF987            0.997680        0.997680        0.997680        0.997680
# ZNF993            0.994012        0.994012        0.994012        0.994012
# ZNF995            0.992161        0.991379        0.991379        0.991379
# ZP2               1.000000        1.000000        1.000000        1.000000
#
#             cluster.9_spec  cluster.10_spec  ...  cluster.20_spec  \
# Unnamed: 0                                   ...
# SYN3              0.996942         0.996942  ...         0.996942
# PTPRO             0.746464         0.746464  ...         0.746464
# EPS8              0.934483         0.934483  ...         0.934483
# TBK1              0.810811         0.810811  ...         0.810811
# GPR19             0.918367         0.918367  ...         0.918367
# ...                    ...              ...  ...              ...
# ZNF985            0.985507         0.985507  ...         0.985507
# ZNF987            0.997680         0.998880  ...         0.997680
# ZNF993            0.994012         0.994012  ...         0.994012
# ZNF995            0.991379         0.991379  ...         0.991379
# ZP2               1.000000         1.000000  ...         1.000000
#
#             cluster.21_spec  cluster.22_spec  cluster.23_spec  \
# Unnamed: 0
# SYN3               0.996942         0.996942         0.996942
# PTPRO              0.746464         0.746464         0.746464
# EPS8               0.934483         0.934483         0.934483
# TBK1               0.810811         0.810811         0.810811
# GPR19              0.918367         0.918367         0.918367
# ...                     ...              ...              ...
# ZNF985             0.985507         0.985507         0.987013
# ZNF987             0.997680         0.997680         0.997680
# ZNF993             0.994012         0.994012         0.994012
# ZNF995             0.991379         0.991379         0.991379
# ZP2                1.000000         1.000000         1.000000
#
#             cluster.24_spec  cluster.25_spec  cluster.26_spec  \
# Unnamed: 0
# SYN3               0.996942         0.996942         0.996942
# PTPRO              0.746464         0.746464         0.746464
# EPS8               0.934483         0.934483         0.934483
# TBK1               0.810811         0.810811         0.810811
# GPR19              0.918367         0.918367         0.918367
# ...                     ...              ...              ...
# ZNF985             0.985507         0.985507         0.985507
# ZNF987             0.997680         0.997680         0.997680
# ZNF993             0.996942         0.994012         0.994012
# ZNF995             0.991379         0.991379         0.991379
# ZP2                1.000000         1.000000         1.000000
#
#             cluster.27_spec  cluster.28_spec  cluster.29_spec
# Unnamed: 0
# SYN3               0.996942         0.996942         0.996942
# PTPRO              0.746464         0.746464         0.746464
# EPS8               0.934483         0.934483         0.934483
# TBK1               0.810811         0.810811         0.844828
# GPR19              0.918367         0.933735         0.918367
# ...                     ...              ...              ...
# ZNF985             0.985507         0.985507         0.985507
# ZNF987             0.997680         0.997680         0.997680
# ZNF993             0.994012         0.994012         0.994012
# ZNF995             0.991379         0.991379         0.991379
# ZP2                1.000000         1.000000         1.000000
#
# [24105 rows x 29 columns]

# %%
df_spec.to_csv("Larval_RGC.gene.expr.spec.csv")

# %%
#test an api call
tissue = "Cone"
weight = 50
number = 144
percent =  weight / 100
cov = df[tissue]
spec = df_spec[tissue + "_spec"]
cov_weighted = df[tissue] * percent
spec_weighted = df_spec[tissue + "_spec"] * (1 - percent)

sum = cov + spec

sum = sum.sort_values(ascending=False)

list = []
for gene in sum.iloc[:number].index:
    list.append({"data": gene, "x": cov[gene], "y": spec[gene]})
list[143]
# Out:
# {'data': 'march1', 'x': 0.347683207, 'y': 0.936218679}

# %%
df.loc["zgc:158463",]
# Out:
# Amacrine       1.000000
# Bipolar        1.000000
# Cone           0.999671
# Cornea         1.000000
# Horizontal     0.999592
# Muller Glia    1.000000
# RGC            1.000000
# Rod            1.000000
# RPE            1.000000
# Name: zgc:158463, dtype: float64
