# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Retina.gene.expr.pct.csv")
df
# Out:
#             Unnamed: 0  Amacrine   Bipolar     Cones    Cornea  Horizontal  \
# 0               ptpn12  0.001934  0.004834  0.003286  0.002677    0.001631
# 1                phtf2  0.002256  0.001208  0.000657  0.001339    0.001631
# 2              phtf2.1  0.013213  0.007183  0.003286  0.006693    0.006117
# 3           CU856344.1  0.000000  0.000000  0.002300  0.001339    0.000408
# 4      si:zfos-932h1.3  0.003545  0.001477  0.002300  0.004016    0.001223
# ...                ...       ...       ...       ...       ...         ...
# 26661   CABZ01025311.2  0.000000  0.000000  0.000000  0.000000    0.000000
# 26662   CABZ01049625.1  0.000000  0.000000  0.000000  0.000000    0.000000
# 26663   CABZ01109021.1  0.000000  0.000000  0.000329  0.000000    0.000000
# 26664   CABZ01065076.1  0.000000  0.000000  0.000000  0.000000    0.000000
# 26665        taar10c.1  0.000000  0.000000  0.000000  0.000000    0.000000
#
#        MullerGlia       RGC      Rods       RPE
# 0        0.002469  0.003167  0.002278  0.007485
# 1        0.003292  0.003167  0.000000  0.001497
# 2        0.004938  0.022961  0.002278  0.004491
# 3        0.008230  0.001584  0.000000  0.000000
# 4        0.003292  0.004751  0.002278  0.004491
# ...           ...       ...       ...       ...
# 26661    0.000000  0.000000  0.000000  0.000000
# 26662    0.000000  0.000000  0.000000  0.000000
# 26663    0.000000  0.000000  0.000000  0.000000
# 26664    0.000000  0.000000  0.000000  0.000000
# 26665    0.000000  0.000000  0.000000  0.000000
#
# [26666 rows x 10 columns]

# %%
df = df.set_index("Unnamed: 0")
df
# Out:
#                  Amacrine   Bipolar     Cones    Cornea  Horizontal  \
# Unnamed: 0
# ptpn12           0.001934  0.004834  0.003286  0.002677    0.001631
# phtf2            0.002256  0.001208  0.000657  0.001339    0.001631
# phtf2.1          0.013213  0.007183  0.003286  0.006693    0.006117
# CU856344.1       0.000000  0.000000  0.002300  0.001339    0.000408
# si:zfos-932h1.3  0.003545  0.001477  0.002300  0.004016    0.001223
# ...                   ...       ...       ...       ...         ...
# CABZ01025311.2   0.000000  0.000000  0.000000  0.000000    0.000000
# CABZ01049625.1   0.000000  0.000000  0.000000  0.000000    0.000000
# CABZ01109021.1   0.000000  0.000000  0.000329  0.000000    0.000000
# CABZ01065076.1   0.000000  0.000000  0.000000  0.000000    0.000000
# taar10c.1        0.000000  0.000000  0.000000  0.000000    0.000000
#
#                  MullerGlia       RGC      Rods       RPE
# Unnamed: 0
# ptpn12             0.002469  0.003167  0.002278  0.007485
# phtf2              0.003292  0.003167  0.000000  0.001497
# phtf2.1            0.004938  0.022961  0.002278  0.004491
# CU856344.1         0.008230  0.001584  0.000000  0.000000
# si:zfos-932h1.3    0.003292  0.004751  0.002278  0.004491
# ...                     ...       ...       ...       ...
# CABZ01025311.2     0.000000  0.000000  0.000000  0.000000
# CABZ01049625.1     0.000000  0.000000  0.000000  0.000000
# CABZ01109021.1     0.000000  0.000000  0.000000  0.000000
# CABZ01065076.1     0.000000  0.000000  0.000000  0.000000
# taar10c.1          0.000000  0.000000  0.000000  0.000000
#
# [26666 rows x 9 columns]

# %%
df = df.rename(columns={"Amacrine": "Amacrine", "Bipolar": "Bipolar", "Cones":"Cone", "Cornea": "Cornea", "Horizontal": "Horizontal", \
                	"MullerGlia": "Muller Glia", "RGC": "RGC", "Rods": "Rod", "RPE": "RPE"})

# %%
df.to_csv("Retina.gene.expr.renamed.csv")

# %%
collist = []
for name in df.columns:
    collist.append(name + "_spec")
collist
# Out:
# ['Amacrine_spec',
#  'Bipolar_spec',
#  'Cone_spec',
#  'Cornea_spec',
#  'Horizontal_spec',
#  'Muller Glia_spec',
#  'RGC_spec',
#  'Rod_spec',
#  'RPE_spec']

# %%
df_spec = pd.DataFrame(columns=collist)
df_spec
# Out:
# Empty DataFrame
# Columns: [Amacrine_spec, Bipolar_spec, Cone_spec, Cornea_spec, Horizontal_spec, Muller Glia_spec, RGC_spec, Rod_spec, RPE_spec]
# Index: []

# %%
for column in df.columns:
    max = df.drop(column, axis=1).max(axis=1)
    df_spec[column + "_spec"] = 1 - max
df_spec
# Out:
#                  Amacrine_spec  Bipolar_spec  Cone_spec  Cornea_spec  \
# Unnamed: 0
# ptpn12                0.992515      0.992515   0.992515     0.992515
# phtf2                 0.996708      0.996708   0.996708     0.996708
# phtf2.1               0.977039      0.977039   0.977039     0.977039
# CU856344.1            0.991770      0.991770   0.991770     0.991770
# si:zfos-932h1.3       0.995249      0.995249   0.995249     0.995249
# ...                        ...           ...        ...          ...
# CABZ01025311.2        1.000000      1.000000   1.000000     1.000000
# CABZ01049625.1        1.000000      1.000000   1.000000     1.000000
# CABZ01109021.1        0.999671      0.999671   1.000000     0.999671
# CABZ01065076.1        1.000000      1.000000   1.000000     1.000000
# taar10c.1             1.000000      1.000000   1.000000     1.000000
#
#                  Horizontal_spec  Muller Glia_spec  RGC_spec  Rod_spec  \
# Unnamed: 0
# ptpn12                  0.992515          0.992515  0.992515  0.992515
# phtf2                   0.996708          0.996833  0.996708  0.996708
# phtf2.1                 0.977039          0.977039  0.986787  0.977039
# CU856344.1              0.991770          0.997700  0.991770  0.991770
# si:zfos-932h1.3         0.995249          0.995249  0.995509  0.995249
# ...                          ...               ...       ...       ...
# CABZ01025311.2          1.000000          1.000000  1.000000  1.000000
# CABZ01049625.1          1.000000          1.000000  1.000000  1.000000
# CABZ01109021.1          0.999671          0.999671  0.999671  0.999671
# CABZ01065076.1          1.000000          1.000000  1.000000  1.000000
# taar10c.1               1.000000          1.000000  1.000000  1.000000
#
#                  RPE_spec
# Unnamed: 0
# ptpn12           0.995166
# phtf2            0.996708
# phtf2.1          0.977039
# CU856344.1       0.991770
# si:zfos-932h1.3  0.995249
# ...                   ...
# CABZ01025311.2   1.000000
# CABZ01049625.1   1.000000
# CABZ01109021.1   0.999671
# CABZ01065076.1   1.000000
# taar10c.1        1.000000
#
# [26666 rows x 9 columns]

# %%
df_spec.to_csv("spec.csv")

# %%
#test an api call
tissue = "Cone"
weight = 50
number = 144
percent =  weight / 100
cov = df[tissue]
spec = df_spec[tissue + "_spec"]
cov_weighted = df[tissue] * percent
spec_weighted = df_spec[tissue + "_spec"] * (1 - percent)

sum = cov + spec

sum = sum.sort_values(ascending=False)

list = []
for gene in sum.iloc[:number].index:
    list.append({"data": gene, "x": cov[gene], "y": spec[gene]})
list[143]
# Out:
# {'data': 'march1', 'x': 0.347683207, 'y': 0.936218679}

# %%
df.loc["zgc:158463",]
# Out:
# Amacrine       1.000000
# Bipolar        1.000000
# Cone           0.999671
# Cornea         1.000000
# Horizontal     0.999592
# Muller Glia    1.000000
# RGC            1.000000
# Rod            1.000000
# RPE            1.000000
# Name: zgc:158463, dtype: float64
