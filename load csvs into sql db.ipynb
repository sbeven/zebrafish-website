# %%
import pandas as pd 
import sqlalchemy 
import pymysql 
from sqlalchemy import create_engine 
from sqlalchemy import select
from sqlalchemy import text
connection_string = "mysql+pymysql://admin:faaZa=[h5rh&@72.167.69.4:3306/Genes"
engine = create_engine(connection_string, echo=True)
conn = engine.connect()
import os
import pandas as pd 
filepath = "C:\\Users\\drago\\OneDrive\\Documents\\zebrafish website\\csvs"
l = os.listdir(filepath)
for i in range(0, len(l), 2):
    print(l[i])
    print(l[i + 1])
    name1 = l[i][:-8]
    name2 = name1 + "_join"
    print(name1, name2)
    df1 = pd.read_csv(filepath + "\\" + l[i])
    df2 = pd.read_csv(filepath + "\\" + l[i + 1])
    print(df1)
    print(df2)
    df2 = df2.drop("Gene", axis=1)

    df = pd.concat([df1, df2], axis=1)
    df1.to_sql(name1, conn, if_exists="replace", index=False)
    df.to_sql(name2, conn, if_exists="replace", index=False)
conn.close()
# Out:
# 2024-01-08 13:41:36,311 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-01-08 13:41:36,312 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-08 13:41:36,446 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-01-08 13:41:36,447 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-08 13:41:36,513 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-01-08 13:41:36,514 INFO sqlalchemy.engine.Engine [raw sql] {}
# Zebrafish_Hindbrain_16hpf.24hpf.44hpf_cov.csv
# Zebrafish_Hindbrain_16hpf.24hpf.44hpf_spec.csv
# Zebrafish_Hindbrain_16hpf.24hpf.44hpf Zebrafish_Hindbrain_16hpf.24hpf.44hpf_join
#              Gene  DifferentiatingProgenitors_44hpf  DorsalProgenitors_24hpf  \
# 0           rpl24                          0.997717                 1.000000
# 1           cep97                          0.035388                 0.127036
# 2          nfkbiz                          0.000000                 0.000000
# ...

# %%
import pandas as pd 
import sqlalchemy 
import pymysql 
from sqlalchemy import create_engine 
from sqlalchemy import select
from sqlalchemy import text
connection_string = "mysql+pymysql://admin:faaZa=[h5rh&@72.167.69.4:3306/Genes"
engine = create_engine(connection_string, echo=True)
conn = engine.connect()
import os
import pandas as pd 
filepath = "C:\\Users\\drago\\OneDrive\\Documents\\zebrafish website\\csvs"
filename1 = "Zebrafish_InnerEar_12m_cov.csv"
filename2 = "Zebrafish_InnerEar_12m_spec.csv"
name1 = filename1[:-8]
name2 = name1 + "_join"
print(name1, name2)
df1 = pd.read_csv(filepath + "\\" + filename1)
df2 = pd.read_csv(filepath + "\\" + filename2)
print(df1)
print(df2)
df2 = df2.drop("Gene", axis=1)

df = pd.concat([df1, df2], axis=1)
df1.to_sql(name1, conn, if_exists="replace", index=False)
df.to_sql(name2, conn, if_exists="replace", index=False)
conn.close()
# Out:
# 2024-01-18 11:37:47,888 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-01-18 11:37:47,888 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-18 11:37:48,021 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-01-18 11:37:48,021 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-18 11:37:48,087 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-01-18 11:37:48,088 INFO sqlalchemy.engine.Engine [raw sql] {}
# Zebrafish_InnerEar_12m Zebrafish_InnerEar_12m_join
#                    Gene  Crista.SCs       HCs  Macula.SCs       max  \
# 0            CR383668.1         0.0  0.000000    0.000000  0.000000
# 1              fgfr1op2         0.0  0.021587    0.000000  0.021587
# 2      si:dkey-21h14.12         0.0  0.000000    0.000000  0.000000
# 3      si:dkey-285e18.2         0.0  0.000000    0.000000  0.000000
# 4               znf1114         0.0  0.005079    0.008197  0.008197
# ...                 ...         ...       ...         ...       ...
# ...
